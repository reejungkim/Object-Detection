# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['test', 'sample_submission.csv']

# %%
images = os.listdir("../input/test")
images
# Out:
# ['b4c3b52a8723d431.jpg',
#  '631bb0244ef594e6.jpg',
#  '584541c62119b661.jpg',
#  'b63a034708d455f2.jpg',
#  'bfac59b803102f50.jpg',
#  '96c575586a023544.jpg',
#  'd36d0f270bb05dc9.jpg',
#  '0acfd7e62c7c7f7a.jpg',
#  '56381bb8189eb0d2.jpg',
#  'a6946aa9c3dca189.jpg',
#  '6ddd89e225f4a3bb.jpg',
#  '0589ccd1c103f3b8.jpg',
#  '26b0a4dfb86f9072.jpg',
#  '5f277e05fefd8517.jpg',
#  '773eb0cfe93af28f.jpg',
#  '2b595c3e5d02590b.jpg',
#  '83bea8d7b1523da6.jpg',
#  '7e1fa6edf6e718dc.jpg',
#  'e8179c7dcb15d774.jpg',
#  '4d88ba5fa934d06e.jpg',
#  '1635b32aff09a703.jpg',
#  '754a4a0b77029a76.jpg',
#  'cba72af726865dc3.jpg',
#  'ad5003ca1db5821c.jpg',
#  '54da744f994890f8.jpg',
#  'e7169ea7f709a869.jpg',
#  '5f5acdb60d882e85.jpg',
#  'e4db125883d480fb.jpg',
#  'b905bd45e5ec860b.jpg',
#  '25eb9e25feb22d56.jpg',
#  'a4c68f4d8071adbc.jpg',
#  'f9e3d154e93896a2.jpg',
#  '9c5a1d41ae7661d4.jpg',
#  'a0d0c33d5abba1a8.jpg',
#  '10f7568d93c4c98a.jpg',
#  'c749134adf3da801.jpg',
#  '661c4d413f11b137.jpg',
# ...

# %%
pd.read_csv("../input/sample_submission.csv").head()
# Out:
#             ImageId                                   PredictionString
# 0  b5d912e06f74e948  /m/05s2s 0.9 0.46 0.08 0.93 0.5 /m/0c9ph5 0.5 ...
# 1  be137cf6bb0b62d5  /m/05s2s 0.9 0.46 0.08 0.93 0.5 /m/0c9ph5 0.5 ...
# 2  8d65ca08cb5ce8e8  /m/05s2s 0.9 0.46 0.08 0.93 0.5 /m/0c9ph5 0.5 ...
# 3  4d3ad1e52ad8c065  /m/05s2s 0.9 0.46 0.08 0.93 0.5 /m/0c9ph5 0.5 ...
# 4  9b94408691c7d7bf  /m/05s2s 0.9 0.46 0.08 0.93 0.5 /m/0c9ph5 0.5 ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# Load an color image in grayscale
img = cv2.imread('../input/test/b4c3b52a8723d431.jpg',0)
#img=mpimg.imread('b4c3b52a8723d431.jpg')

# %%
img
# Out:
# array([[87, 89, 91, ..., 94, 92, 91],
#        [91, 92, 92, ..., 95, 94, 95],
#        [94, 93, 92, ..., 96, 95, 98],
#        ...,
#        [27, 23, 17, ...,  3,  3,  3],
#        [22, 20, 18, ...,  4,  4,  4],
#        [17, 17, 19, ...,  4,  4,  4]], dtype=uint8)

# %%
plt.imshow(img)

# %%
plt.imshow(img, cmap=plt.cm.gray)

# %%
a= cv2.imread('..input/test/8afec474dd8f5c37.jpg', 0)
#plt.imshow(a)
(a)

# %%
from PIL import Image

img = Image.open('..input/test/8afec474dd8f5c37.jpg')
img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-75-50c565e4bb9f> in <module>()
#       1 from PIL import Image
#       2
# ----> 3 img = Image.open('..input/test/8afec474dd8f5c37.jpg')
#       4 img.show()
#
# /opt/conda/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2546
#    2547     if filename:
# -> 2548         fp = builtins.open(filename, "rb")
#    2549         exclusive_fp = True
#    2550
#
# FileNotFoundError: [Errno 2] No such file or directory: '..input/test/8afec474dd8f5c37.jpg'

# %%
images
# Out:
# ['b4c3b52a8723d431.jpg',
#  '631bb0244ef594e6.jpg',
#  '584541c62119b661.jpg',
#  'b63a034708d455f2.jpg',
#  'bfac59b803102f50.jpg',
#  '96c575586a023544.jpg',
#  'd36d0f270bb05dc9.jpg',
#  '0acfd7e62c7c7f7a.jpg',
#  '56381bb8189eb0d2.jpg',
#  'a6946aa9c3dca189.jpg',
#  '6ddd89e225f4a3bb.jpg',
#  '0589ccd1c103f3b8.jpg',
#  '26b0a4dfb86f9072.jpg',
#  '5f277e05fefd8517.jpg',
#  '773eb0cfe93af28f.jpg',
#  '2b595c3e5d02590b.jpg',
#  '83bea8d7b1523da6.jpg',
#  '7e1fa6edf6e718dc.jpg',
#  'e8179c7dcb15d774.jpg',
#  '4d88ba5fa934d06e.jpg',
#  '1635b32aff09a703.jpg',
#  '754a4a0b77029a76.jpg',
#  'cba72af726865dc3.jpg',
#  'ad5003ca1db5821c.jpg',
#  '54da744f994890f8.jpg',
#  'e7169ea7f709a869.jpg',
#  '5f5acdb60d882e85.jpg',
#  'e4db125883d480fb.jpg',
#  'b905bd45e5ec860b.jpg',
#  '25eb9e25feb22d56.jpg',
#  'a4c68f4d8071adbc.jpg',
#  'f9e3d154e93896a2.jpg',
#  '9c5a1d41ae7661d4.jpg',
#  'a0d0c33d5abba1a8.jpg',
#  '10f7568d93c4c98a.jpg',
#  'c749134adf3da801.jpg',
#  '661c4d413f11b137.jpg',
# ...
